# %% [markdown]
# ## ENGIE - GEMS
# ### Evaluación de las habilidades de gestión de datos y digitalización
#
# ---
# Prueba práctica del proceso de selección desarrollada por Alba Durán Merinero

# %% [markdown]
# #### 1. Configuración de paths y librerías

# %%
import funciones_caso_practico as f

main_path = "datos/" 
facturas_path = main_path + "facturas_agiekey.xlsx"
facturas_path2 = main_path + "facturas_agiekey2.xlsx"
mapping_path = main_path + "Mapping.xlsx"
deals_path = main_path + "Deals_Marzo_2024/"

# %% [markdown]
# #### 2. Análisis dataset Facturas Agiekey

# %%
#Carga del fichero de facturas
facturas = f.carga_xlsx(facturas_path)
facturas.head()
# Out:
#   NumeroFactura       Emisor       RazonSocialEmisor DepEmisor     Receptor  \
# 0    2024264672  ESA86484292         ENAGAS GTS, SAU        60  ESB82508441
# 1    2024264671  ESA86484292         ENAGAS GTS, SAU        60  ESB82508441
# 2    2324004231  ESA86484334  ENAGAS TRANSPORTE, SAU       NaN  ESB82508441
# 3    2024164592  ESA86484292         ENAGAS GTS, SAU        50  ESB82508441
# 4    2024164591  ESA86484292         ENAGAS GTS, SAU        50  ESB82508441
#
#   RazonSocialReceptor DepReceptor FechaFactura    Importe Moneda    Estado  \
# 0    ENGIE ESPAÑA SLU         NaN       4/3/24  123195.13    EUR  Recibida
# 1    ENGIE ESPAÑA SLU         NaN       4/3/24  111963.62    EUR  Recibida
# 2    ENGIE ESPAÑA SLU         NaN       6/3/24  503763.47    EUR  Recibida
# 3    ENGIE ESPAÑA SLU         NaN       4/3/24    1375.12    EUR  Recibida
# 4    ENGIE ESPAÑA SLU         NaN       4/3/24    1787.43    EUR  Recibida
#
# ...

# %%
#Extracción de información básica del dataset de facturas
facturas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   NumeroFactura        14 non-null     object
#  1   Emisor               14 non-null     object
#  2   RazonSocialEmisor    14 non-null     object
#  3   DepEmisor            13 non-null     object
#  4   Receptor             14 non-null     object
#  5   RazonSocialReceptor  14 non-null     object
#  6   DepReceptor          0 non-null      object
#  7   FechaFactura         14 non-null     object
#  8   Importe              14 non-null     object
#  9   Moneda               14 non-null     object
#  10  Estado               14 non-null     object
#  11  FechaEstado          14 non-null     object
#  12  FechaRegistro        14 non-null     object
#  13  Destino              14 non-null     object
#  14  Contrato             14 non-null     object
# ...

# %%
#Verificación de que las facturas del archivo, cumplen con los requisitos definidos para una factura, en caso contrario, se derivarán esas facturas a otra tabla
#Facturas validadas como correctas
facturas_validas = f.valid_invoices(facturas)
facturas_validas.head()
# Out:
# Todas las facturas del archivo son válidas.
#   NumeroFactura       Emisor       RazonSocialEmisor DepEmisor     Receptor  \
# 0    2024264672  ESA86484292         ENAGAS GTS, SAU        60  ESB82508441
# 1    2024264671  ESA86484292         ENAGAS GTS, SAU        60  ESB82508441
# 2    2324004231  ESA86484334  ENAGAS TRANSPORTE, SAU       NaN  ESB82508441
# 3    2024164592  ESA86484292         ENAGAS GTS, SAU        50  ESB82508441
# 4    2024164591  ESA86484292         ENAGAS GTS, SAU        50  ESB82508441
#
#   RazonSocialReceptor DepReceptor FechaFactura    Importe Moneda    Estado  \
# 0    ENGIE ESPAÑA SLU         NaN       4/3/24  123195.13    EUR  Recibida
# 1    ENGIE ESPAÑA SLU         NaN       4/3/24  111963.62    EUR  Recibida
# 2    ENGIE ESPAÑA SLU         NaN       6/3/24  503763.47    EUR  Recibida
# 3    ENGIE ESPAÑA SLU         NaN       4/3/24    1375.12    EUR  Recibida
# 4    ENGIE ESPAÑA SLU         NaN       4/3/24    1787.43    EUR  Recibida
#
# ...

# %%
#Facturas encontradas como no válidas 
facturas_no_validas = f.invalid_invoices(facturas)
facturas_no_validas
# Out:
# El archivo contenía 0 facturas no validas
# Empty DataFrame
# Columns: [NumeroFactura, Emisor, RazonSocialEmisor, DepEmisor, Receptor, RazonSocialReceptor, DepReceptor, FechaFactura, Importe, Moneda, Estado, FechaEstado, FechaRegistro, Destino, Contrato, Origen, ServicioFacturado, ¿Verificada por BO?, Observaciones]
# Index: []

# %%
#Calculo de totales para las facturas válidas
info = f.global_info(facturas_validas)
info
# Out:
#    NumeroFacturasValidas  NumeroClientes FacturacionTotal
# 0                     14               2     811357.98EUR

# %%
#Calculo de totales, a nivel de cada cliente presente en el archivo
clientes = f.client_info(facturas_validas)
clientes
# Out:
#         RazonSocialEmisor      Emisor  NumeroOrigenes NumServiciosFacturados  \
# 0         ENAGAS GTS, SAU  ESA86484292              2                      2
# 0  ENAGAS TRANSPORTE, SAU  ESA86484334              1                      1
#
#   NumeroFacturas FacturacionTotal
# 0             13     307594.51EUR
# 0              1     503763.47EUR

# %% [markdown]
# A partir del dataset de Facturas proporciona, se ha creado otro dataset que contuviera facturas con campos no informados o corruptos.
# Aseguramos así el correcto funcionamiento del código en esos casos, este dataset se ha llamado **facturas_agiekey2.xlsx**

# %%
#Carga del fichero de facturas
facturas2 = f.carga_xlsx(facturas_path2)

#Verificación de que las facturas del archivo, cumplen con los requisitos definidos para una factura, en caso contrario, se derivarán esas facturas a otra tabla
#Facturas validadas como correctas
facturas_validas2 = f.valid_invoices(facturas2)
facturas_validas2.head()
# Out:
# El archivo contenía 3 facturas no validas, por favor ejecute la función invalid_invoices.
#   NumeroFactura       Emisor RazonSocialEmisor DepEmisor     Receptor  \
# 0    2024164592  ESA86484292   ENAGAS GTS, SAU        50  ESB82508441
# 1    2024164591  ESA86484292   ENAGAS GTS, SAU        50  ESB82508441
# 2    2024164590  ESA86484292   ENAGAS GTS, SAU        50  ESB82508441
# 3    2024164589  ESA86484292   ENAGAS GTS, SAU        50  ESB82508441
# 4    2024164587  ESA86484292   ENAGAS GTS, SAU        50  ESB82508441
#
#   RazonSocialReceptor DepReceptor FechaFactura  Importe Moneda    Estado  \
# 0    ENGIE ESPAÑA SLU         NaN       4/3/24  1375.12    EUR  Recibida
# 1    ENGIE ESPAÑA SLU         NaN       4/3/24  1787.43    EUR  Recibida
# 2    ENGIE ESPAÑA SLU         NaN       4/3/24  1930.23    EUR  Recibida
# 3    ENGIE ESPAÑA SLU         NaN       4/3/24  1472.13    EUR  Recibida
# 4    ENGIE ESPAÑA SLU         NaN       4/3/24  1041.67    EUR  Recibida
#
# ...

# %%
facturas2 = f.carga_xlsx(facturas_path2)
facturas_validas2 = f.valid_invoices(facturas2)
facturas_no_validas2 = f.invalid_invoices(facturas2)
# Out:
# El archivo contenía 3 facturas no validas, por favor ejecute la función invalid_invoices.
# El archivo contenía 2 facturas no validas

# %%
#Facturas encontradas como no válidas 
facturas_no_validas2 = f.invalid_invoices(facturas2)
facturas_no_validas2
# Out:
# El archivo contenía 2 facturas no validas
#   NumeroFactura       Emisor       RazonSocialEmisor DepEmisor     Receptor  \
# 0    2324004231  ESA86484334  ENAGAS TRANSPORTE, SAU       NaN  ESB82508441
# 1    2024164586  ESA86484292         ENAGAS GTS, SAU        50  ESB82508441
#
#   RazonSocialReceptor DepReceptor FechaFactura  Importe Moneda    Estado  \
# 0    ENGIE ESPAÑA SLU         NaN       6/3/24      NaN    EUR  Recibida
# 1                 NaN         NaN       4/3/24  1030.97    EUR  Recibida
#
#   FechaEstado FechaRegistro Destino   Contrato        Origen  \
# 0      6/3/24        6/3/24   eMail  300289985  C.I. Almería
# 1      4/3/24        4/3/24   eMail     344991           TVB
#
#     ServicioFacturado ¿Verificada por BO? Observaciones
# 0         Entrada PVB                 NaN           NaN
# 1  Almacenamiento TVB                 NaN           NaN

# %%
#Calculo de totales para las facturas válidas del segundo fichero
info2 = f.global_info(facturas_validas2)
info2
# Out:
#    NumeroFacturasValidas  NumeroClientes FacturacionTotal
# 0                      9               1      69439.13EUR

# %%
#Calculo de totales, a nivel de cada cliente presente en el segundo archivo
clientes2 = f.client_info(facturas_validas2)
clientes2
# Out:
#   RazonSocialEmisor      Emisor  NumeroOrigenes NumServiciosFacturados  \
# 0   ENAGAS GTS, SAU  ESA86484292              1                      1
#
#   NumeroFacturas FacturacionTotal
# 0              9      69439.13EUR

# %% [markdown]
# #### 3. Análisis dataset Mapping

# %%
#Carga del fichero de mapping
mapping = f.carga_xlsx(mapping_path)
mapping.head()
# Out:
#          Origen Servicio facturado Portfolio Commodity DealType
# 0  C.I. Almería        Entrada PVB     MEDG2       IAC    GETRA
# 1           TVB            PLANTAS     JVLNG       ICC    GETRA
# 2           TVB            PLANTAS     JVLNG       ICC    GETRA
# 3           TVB            PLANTAS     JVLNG       ICC    GETRA
# 4           TVB            PLANTAS     JVLNG       ICC    GETRA

# %%
#Extracción de información básica del dataset de mapping
mapping.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Origen              47 non-null     object
#  1   Servicio facturado  47 non-null     object
#  2   Portfolio           43 non-null     object
#  3   Commodity           43 non-null     object
#  4   DealType            43 non-null     object
# dtypes: object(5)
# memory usage: 2.0+ KB

# %% [markdown]
# #### 4. Análisis archivos Deals_Marzo_2024.zip

# %%
#Rutas de los ficheros
path1 = deals_path + 'JVLNG_CTV_STOK_MARZO_2024_05_23_14_12.xlsx'
path2 = deals_path + 'MEDG2_IAC_GETRA_MARZO_2024_05_23_14_12.xlsx'
path3 = deals_path + 'SUGS2_AOC_STOK_MARZO_2024_05_23_14_12.xlsx'
path4 = deals_path + 'SUGST_AOC_STOK_MARZO_2024_05_23_14_12.xlsx'

# %%
deals1 = f.carga_xlsx(path1)
print(deals1.info())
print(deals1.shape)
deals1.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Columns: 108 entries, Unnamed: 0 to OrderId
# dtypes: object(108)
# memory usage: 35.6+ KB
# None
# (42, 108)
#   Unnamed: 0                       AggregatedKey ApplicationPeriod  \
# 0          0  42563586,2024/05/20 13:35:59,GEFWD            010524
# 1          1  42518127,2024/05/20 13:34:13,GEFWD            040624
# 2          2  42518126,2024/05/20 13:35:59,GEFWD            010624
# 3          3  42518125,2024/05/20 13:35:59,GEFWD            010524
# 4          4  42518124,2024/05/20 13:35:59,GEFWD            280424
#
#   BookingSource BOValidated           BOValidationDate BOValidator  \
# 0           MET        True  2024-05-20T13:35:59+02:00      GGH410
# 1           MET        True  2024-05-20T13:34:13+02:00      GGH410
# 2           MET        True  2024-05-20T13:35:59+02:00      GGH410
# 3           MET        True  2024-05-20T13:35:59+02:00      GGH410
# ...

# %%
deals2 = f.carga_xlsx(path2)
print(deals2.info())
print(deals2.shape)
deals2.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 86 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            2 non-null      object
#  1   AggregatedKey         2 non-null      object
#  2   ApplicationPeriod     2 non-null      object
#  3   AuctionType           0 non-null      object
#  4   BookingSource         2 non-null      object
#  5   BOValidated           2 non-null      object
#  6   BOValidationDate      2 non-null      object
#  7   BOValidator           2 non-null      object
#  8   CancelsDealId         2 non-null      object
#  9   Capacity              2 non-null      object
#  10  CapacityFrequency     2 non-null      object
#  11  CapacityUnit          2 non-null      object
#  12  Category              2 non-null      object
#  13  Clearer               2 non-null      object
#  14  ClientType            2 non-null      object
# ...

# %%
deals3 = f.carga_xlsx(path3)
print(deals3.info())
print(deals3.shape)
deals3.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 97 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             13 non-null     object
#  1   AggregatedKey          13 non-null     object
#  2   ApplicationPeriod      9 non-null      object
#  3   BookingSource          13 non-null     object
#  4   BOValidated            13 non-null     object
#  5   BOValidationDate       13 non-null     object
#  6   BOValidator            9 non-null      object
#  7   CancelsDealId          13 non-null     object
#  8   Capacity               9 non-null      object
#  9   CapacityFrequency      13 non-null     object
#  10  CapacityUnit           13 non-null     object
#  11  Category               13 non-null     object
#  12  Clearer                13 non-null     object
#  13  ClientType             13 non-null     object
# ...

# %%
deals4 = f.carga_xlsx(path4)
print(deals4.info())
print(deals4.shape)
deals4.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 96 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             6 non-null      object
#  1   AggregatedKey          6 non-null      object
#  2   BookingSource          6 non-null      object
#  3   BOValidated            6 non-null      object
#  4   BOValidationDate       6 non-null      object
#  5   BOValidator            6 non-null      object
#  6   CancelsDealId          6 non-null      object
#  7   CapacityFrequency      6 non-null      object
#  8   CapacityUnit           6 non-null      object
#  9   Category               6 non-null      object
#  10  Clearer                6 non-null      object
#  11  ClientType             6 non-null      object
#  12  CommodityType          6 non-null      object
#  13  Counterparty           6 non-null      object
# ...
